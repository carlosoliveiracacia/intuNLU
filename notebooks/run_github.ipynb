# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
! ls gdrive/MyDrive/stanford_nlu/
# Out:
#  bakeoff-colors-announcement.gdoc
#  bakeoff-rel_ext-announcement.gdoc
#  bakeoff-rel_ext-test-data.zip
#  bakeoff-wordentail-announcement.gdoc
#  bakeoff-wordentail-data.zip
#  bakeoff-wordsim-announcement.gdoc
#  bakeoff-wordsim-test-data.zip
#  cs224u-colors-bakeoff-data.csv
#  intuNLU
# 'XCS224U Azure Guide.gdoc'
# 'XCS224U Azure Guide（副本）.gdoc'
# 'XCS224U Cohort3 Bake-off1: Word similarity.gslides'

# %%
# %cd gdrive/MyDrive/stanford_nlu/
# Out:
# /content/gdrive/MyDrive/stanford_nlu

# %%
! pwd
# Out:
# /content/gdrive/MyDrive/stanford_nlu

# %%
# %cd intuNLU/
# Out:
# /content/gdrive/My Drive/stanford_nlu/intuNLU

# %%
# !ls
# Out:
# intunlu  notebooks  README.md  setup.py

# %%
# !python setup.py install
# Out:
# /usr/lib/python3.7/distutils/dist.py:274: UserWarning: Unknown distribution option: 'python_version'
#   warnings.warn(msg)
# running install
# running bdist_egg
# running egg_info
# writing intunlu.egg-info/PKG-INFO
# writing dependency_links to intunlu.egg-info/dependency_links.txt
# writing requirements to intunlu.egg-info/requires.txt
# writing top-level names to intunlu.egg-info/top_level.txt
# writing manifest file 'intunlu.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/intunlu
# copying build/lib/intunlu/train.py -> build/bdist.linux-x86_64/egg/intunlu
# copying build/lib/intunlu/finetunning.py -> build/bdist.linux-x86_64/egg/intunlu
# copying build/lib/intunlu/__init__.py -> build/bdist.linux-x86_64/egg/intunlu
# byte-compiling build/bdist.linux-x86_64/egg/intunlu/train.py to train.cpython-37.pyc
# ...

# %%
# %pycat setup.py

# %%
from intunlu.train import *

# %%
train(model_name='t5-small', max_input_length=32, batch_size=2, n_max_epochs=3, random_state=1234, max_num_samples=50)
# Out:
# ...
# 2021-03-16 05:03:34,727 [MainThread  ] [WARNI]  [builder.py:357] [_create_builder_config()] Using custom data configuration default
# ...
# 2021-03-16 05:05:49,992 [MainThread  ] [INFO ]  [train.py:102] [           load_data()] train dataset: initial # of samples is 204045.
# 2021-03-16 05:05:49,994 [MainThread  ] [INFO ]  [train.py:107] [           load_data()] train dataset: will effectively use 50 samples.
# Dataset xsum downloaded and prepared to /root/.cache/huggingface/datasets/xsum/default/1.2.0/f9abaabb5e2b2a1e765c25417264722d31877b34ec34b437c53242f6e5c30d6d. Subsequent calls will reuse this data.
# 2021-03-16 05:05:52,031 [MainThread  ] [WARNI]  [builder.py:357] [_create_builder_config()] Using custom data configuration default
# 2021-03-16 05:05:52,036 [MainThread  ] [WARNI]  [builder.py:512] [download_and_prepare()] Reusing dataset xsum (/root/.cache/huggingface/datasets/xsum/default/1.2.0/f9abaabb5e2b2a1e765c25417264722d31877b34ec34b437c53242f6e5c30d6d)
# ...
